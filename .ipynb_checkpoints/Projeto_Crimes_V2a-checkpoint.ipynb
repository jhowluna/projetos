# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/crimes.csv')

# %%
dados.head()
# Out:
#       id             bairro               created_at  \
# 0  49787            Butantã  2015-06-16 23:34:01.000
# 1  10679           Itaquera  2013-09-11 18:26:31.819
# 2  10682           Itaquera  2013-09-11 18:42:07.858
# 3   6166            Morumbi  2013-08-20 11:56:52.717
# 4   6521  Alto de Pinheiros  2013-08-20 17:41:21.569
#
#                                            descricao  \
# 0  5 bandidos, armas, entraram em casa e vasculha...
# 1  Meu caso foi para o Pequenas Causas, ganhamos ...
# 2  Meu caso foi para o Pequenas Causas, ganhamos ...
# 3  Estava parada no semáforo, o bandido veio e es...
# 4  Arrombaram o porta malas do meu carro e levara...
#
#                                             endereco   id.1 ip_address_origin  \
# 0              Avenida Trona Constanzo, 177, Butantã  49787               NaN
# 1  Avenida José Pinheiro Borges, 450-876 - Itaque...  10679       187.11.1.51
# 2  Rua Corínthians - Itaquera - Shopping Metrô It...  10682     189.19.160.82
# ...

# %%
print(f'Linhas: {dados.shape[0]}')
print(f'Colunas: {dados.shape[0]}')
# Out:
# Linhas: 12899
# Colunas: 12899

# %%
dados.describe()
# Out:
#                  id          id.1      latitude     longitude          sexo  \
# count  12899.000000  12899.000000  12899.000000  12899.000000  12899.000000
# mean   45901.500194  45901.500194    -23.566805    -46.636817      0.612528
# std    24974.232979  24974.232979      0.366295      0.439810      0.487192
# min       21.000000     21.000000    -26.473037    -52.173376      0.000000
# 25%    25176.500000  25176.500000    -23.607056    -46.696776      0.000000
# 50%    44565.000000  44565.000000    -23.567079    -46.648535      1.000000
# 75%    68446.500000  68446.500000    -23.541510    -46.606492      1.000000
# max    88573.000000  88573.000000     -0.013911      0.004533      1.000000
#
#        tipo_assalto_id       user_id  valor_prejuizo
# count     12899.000000   1166.000000    12899.000000
# mean          3.230483  16920.901372     2745.264592
# std           2.831739   5056.911119    11115.126241
# min           1.000000   1900.000000        0.000000
# ...

# %%
dados.corr()
# Out:
#                        id      id.1  latitude  longitude      sexo  \
# id               1.000000  1.000000  0.027791   0.017111  0.024007
# id.1             1.000000  1.000000  0.027791   0.017111  0.024007
# latitude         0.027791  0.027791  1.000000   0.554068  0.014097
# longitude        0.017111  0.017111  0.554068   1.000000  0.013717
# sexo             0.024007  0.024007  0.014097   0.013717  1.000000
# tipo_assalto_id  0.155599  0.155599  0.003093   0.004422  0.063221
# user_id          0.903237  0.903237  0.016073  -0.000424 -0.001027
# valor_prejuizo   0.009185  0.009185 -0.000255   0.007025  0.042932
#
#                  tipo_assalto_id   user_id  valor_prejuizo
# id                      0.155599  0.903237        0.009185
# id.1                    0.155599  0.903237        0.009185
# latitude                0.003093  0.016073       -0.000255
# longitude               0.004422 -0.000424        0.007025
# sexo                    0.063221 -0.001027        0.042932
# ...

# %%
dados['time_atualizado']= [dados['time'].str.split(' ')[i][0] for i in range(len(dados))]
dados['time_atualizado'].to_datetime
dados['created_at_atulizado']= [dados['created_at'].str.split(' ')[i][0] for i in range(len(dados))]
dados['created_at_atulizado'].to_datetime

# %%
dados['time_atualizado'].to_datetime
dados['created_at_atulizado'].to_datetime

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-a86e20d5ccb2> in <module>
# ----> 1 dados['time'].str.split(' ')[0][0].to_datetime
#
# AttributeError: 'str' object has no attribute 'to_datetime'
