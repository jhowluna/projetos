# %%
import pandas as pd
import geopandas as gpd

# %%
base_policia=  gpd.read_file('dados/LAYER_DISTRITO/UNIDADES_DE_POLICIAS.shp',)
filtro = ['PolÃ­cia Ambiental','PolÃ­cia Rodoviaria', ' PolÃ­cia Militar','PolÃ­cia Civil']

# %%
gpd.read_file('dados/mapa.csv',)
# Out:
#                           Local PopulaÃ§Ã£o no Ãºltimo censo geometry
# 0                        CaiuÃ¡                         5039     None
# 1                      Castilho                        18003     None
# 2                       Dracena                        43258     None
# 3              Estrela do Norte                         2658     None
# 4    Euclides da Cunha Paulista                         9585     None
# ..                          ...                          ...      ...
# 640         Nova IndependÃªncia                         3068     None
# 641                 Pirapozinho                        24694     None
# 642         Presidente Prudente                       207610     None
# 643              Santo Expedito                         2803     None
# 644                      Taciba                         5714     None
#
# [645 rows x 3 columns]
